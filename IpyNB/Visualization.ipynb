# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd
import sys
import numpy as np
sys.path.append('C:\\Users\\junaj\\Desktop\\CursoDataScience\\notebooks\\lib\\')
#import utils as utils

# %%
# ?np.arange

# %% [markdown]
# Debemos comprender los datos para conseguir mejores resultados en la aplicacion de algoritmos de machine learning. El camino mas rapido para aprender de nuestros datos es usar la visualización.

# %%
# generate and plot an idealized gaussian
import matplotlib.pyplot as plt
from numpy import arange
from matplotlib import pyplot
from scipy.stats import norm
# x-axis for the plot
x_axis = arange(-3, 3, 0.001)
print(x_axis)
# y-axis as the gaussian
y_axis = norm.pdf(x_axis, 0, 1)
# plot data
pyplot.plot(x_axis, y_axis)
pyplot.show()
# Out:
# [-3.    -2.999 -2.998 ...,  2.997  2.998  2.999]

# %%
U=np.random.uniform(0,1,1000)
lamb=1/5
X=-np.log(1-U)/lamb
n, bins, patches = plt.hist(X, 50, normed=1,
                            facecolor='green', alpha=0.75)
#Add best fit line
from scipy.stats import expon

rv = expon()
lamb = plt.plot(bins, lamb*rv.pdf(bins*lamb), 'r--', linewidth=1)

plt.xlabel('Value')
plt.ylabel('Probability')
plt.title("Uniform Histogram and its PDF")
plt.axis([0, 50, 0, 0.3])
plt.grid(True)
plt.show()

# %%
tips=pd.read_csv('tips.csv',index_col=0)

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **MATPLOTLIB**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# **Line Plot**

# %%
plt.plot(tips.index, tips.total_bill)

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# **BAR PLOT**

# %%
plt.bar( tips.day, tips.index)
# Out:
# <Container object of 244 artists>

# %% [markdown]
# **Histogram Plot**
#
# A histogram plot is generally used to summarize the distribution of a data sample
# A fast way to get an idea of the distribution of each attribute is to look at histograms. Histograms
# group data into bins and provide you a count of the number of observations in each bin. From
# the shape of the bins you can quickly get a feeling for whether an attribute is Gaussian, skewed
# or even has an exponential distribution. It can also help you see possible outliers.

# %%
plt.hist(tips.tip)
# Out:
# (array([ 41.,  79.,  66.,  27.,  19.,   5.,   4.,   1.,   1.,   1.]),
#  array([  1. ,   1.9,   2.8,   3.7,   4.6,   5.5,   6.4,   7.3,   8.2,
#           9.1,  10. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Density plots are another way of getting a quick idea of the distribution of each attribute. The
# plots look like an abstracted histogram with a smooth curve drawn through the top of each bin,
# much like your eye tried to do with the histograms.
#
# We can see the distribution for each attribute is clearer than the histograms.

# %%
tips.tip.plot(kind='density')

# %% [markdown]
# **BOXPLOT**

# %% [markdown]
# Another useful way to review the distribution of each attribute is to use Box and Whisker Plots
# or boxplots for short. Boxplots summarize the distribution of each attribute, drawing a line for
# the median (middle value) and a box around the 25th and 75th percentiles (the middle 50% of
# the data). The whiskers give an idea of the spread of the data and dots outside of the whiskers
# show candidate outlier values (values that are 1.5 times greater than the size of spread of the
# middle 50% of the data).
#
# SIMILAR AL DESCRIBE DE PANDAS

# %%
# %matplotlib notebook
from IPython.display import Image
Image(filename='Boxplot.png')

# %%
pyplot.boxplot(tips["total_bill"])
# Out:
# <img src="data:image/png;base64,...">
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff9f03fdd90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff9f0387310>,
#   <matplotlib.lines.Line2D at 0x7ff9f0387f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff9f0535c50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff9f0383390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff9f03fd790>,
#   <matplotlib.lines.Line2D at 0x7ff9f03fd510>]}

# %% [markdown]
# **Scatter Plot**
#
# A scatter plot, or scatterplot, is generally used to summarize the relationship between two
# paired data samples

# %%
plt.scatter(tips['total_bill'],tips['tip'])

# %% [markdown]
# ### Correlation Matrix Plot
#
# Correlation gives an indication of how related the changes are between two variables. If two
# variables change in the same direction they are positively correlated. If they change in opposite
# directions together (one goes up, one goes down), then they are negatively correlated. You can
# calculate the correlation between each pair of attributes. This is called a correlation matrix. You
# can then plot the correlation matrix and get an idea of which variables have a high correlation
# with each other. This is useful to know, because some machine learning algorithms like linear
# and logistic regression can have poor performance if there are highly correlated input variables
# in your data.

# %%
# %matplotlib inline
# Correlation Matrix Plot
from matplotlib import pyplot
from pandas import read_csv
import numpy
filename = 'diabetes.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
correlations = data.corr()
print(correlations)
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# pedi   0.033561  0.173844
# age    1.000000  0.238356
# class  0.238356  1.000000

# %% [markdown]
# A scatter plot shows the relationship between two variables as dots in two dimensions, one
# axis for each attribute. You can create a scatter plot for each pair of attributes in your data.
# Drawing all these scatter plots together is called a scatter plot matrix.
#
# #### Scatter plots are useful for spotting structured relationships between variables, like whether you could summarize the relationship between two variables with a line.
#
# Attributes with structured relationships may
# also be correlated and good candidates for removal from your dataset.

# %%
#Scatterplot Matrix
from matplotlib import pyplot
from pandas import read_csv
from pandas import scatter_matrix
filename = "diabetes.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=names)
scatter_matrix(data)
pyplot.show()

# %% [markdown]
# **SEABORN**

# %%
sns.distplot(tips["total_bill"],kde=False,bins=20)

# %%
utils.autoclean(tips);

# %%
len(tips)
# Out:
# 244

# %%
sns.distplot(tips["sex"],kde=False,bins=2)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='day',y='tip',data=tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.kdeplot(tips['tip'])

# %%
sns.barplot(x='sex',y='total_bill',data=tips)#this shows mean

# %%
print(tips[tips.sex==0].total_bill.std())
print(tips[tips.sex==0].total_bill.mean())
print(tips[tips.sex==1].total_bill.std())
print(tips[tips.sex==1].total_bill.mean())
# Out:
# 8.009208988951961
# 18.056896551724137
# 9.24646876154476
# 20.744076433121034

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
from IPython.display import Image
Image(filename='Boxplot.png')

# %%
sns.boxplot(x='day',y='tip',data=tips,hue='smoker')

# %%
tc=tips.corr()
sns.heatmap(tc,annot=True,cmap='coolwarm')# high relationship?

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',
           markers=['o','v'],scatter_kws={'s':100})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')
